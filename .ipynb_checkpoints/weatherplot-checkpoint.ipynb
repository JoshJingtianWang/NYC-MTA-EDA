# %% [markdown]
# # Weather MTA

# %% [markdown]
# ## Weather data from NOAA

# %%
import pandas as pd

# %%
weather_data=pd.read_csv('NOAA_data.csv')

# %%
#filter for NY
weather_data=weather_data[weather_data.NAME.str.contains('NY')]

# %%
weather_data.NAME.unique()
# Out:
# array(['WHITE PLAINS 3.1 NNW, NY US', 'LAGUARDIA AIRPORT, NY US',
#        'LEVITTOWN 0.2 E, NY US', 'FLORAL PARK 0.4 W, NY US',
#        'SYOSSET, NY US', 'EAST FARMINGDALE 0.9 W, NY US',
#        'PARSIPPANY TROY HILLS TWP 1.5 N, NJ US',
#        'WESTCHESTER CO AIRPORT, NY US', 'QUEENS 2.1 NE, NY US',
#        'AMITYVILLE 0.6 NNE, NY US', 'BROOKLYN 3.1 NW, NY US',
#        'FARMINGDALE REPUBLIC AIRPORT, NY US', 'NEW YORK 8.8 N, NY US',
#        'BRONX 1.5 NE, NY US',
#        'STUYVESANT SQUARE PARK NEW YORK 4.9 NNW, NY US',
#        'WHEATLEY HEIGHTS 1.0 WSW, NY US', 'PLAINVIEW 0.4 ENE, NY US',
#        'MASSAPEQUA PARK 1.2 N, NY US', 'NEW HYDE PARK 1.6 NE, NY US',
#        'KEARNY 1.7 NW, NJ US', 'MELVILLE 1.6 SW, NY US',
#        'BALDWIN 1.3 S, NY US', 'STATEN ISLAND 1.4 SE, NY US',
#        'STATEN ISLAND 4.5 SSE, NY US', 'ALBERTSON 0.2 SSE, NY US',
#        'LYNBROOK 0.6 ENE, NY US', 'LOCUST VALLEY 0.3 E, NY US',
#        'VALLEY STREAM 0.6 SE, NY US', 'AMITYVILLE 0.1 WSW, NY US',
#        'NORTH BABYLON 0.5 E, NY US', 'WANTAGH 0.3 ESE, NY US',
#        'WANTAGH 1.1 NNE, NY US', 'JACKSON HEIGHTS 0.3 WSW, NY US',
#        'SYOSSET 2.0 SSW, NY US', 'QUEENS 3.4 NNW, NY US',
#        'WEST NYACK 1.3 WSW, NY US', 'JFK INTERNATIONAL AIRPORT, NY US',
#        'PARSIPPANY TROY HILLS TWP 1.3 NE, NJ US',
#        'PLAINEDGE 0.4 WSW, NY US', 'FLORAL PARK 0.7 ESE, NY US',
#        'NORTH WANTAGH 0.4 WSW, NY US', 'CENTERPORT, NY US',
#        'MERRICK 1.2 N, NY US', 'PORT WASHINGTON 0.8 N, NY US',
#        'ARMONK 0.3 SE, NY US', 'CENTERPORT 0.9 SW, NY US',
#        'COPIAGUE 0.4 ENE, NY US', 'NY CITY CENTRAL PARK, NY US',
#        'MIDDLE VILLAGE 0.5 SW, NY US', 'LYNBROOK 0.3 NW, NY US',
#        'MASSAPEQUA 0.9 SSW, NY US', 'HICKSVILLE 1.3 ENE, NY US',
#        'ELMSFORD 0.8 SSW, NY US'], dtype=object)

# %%
weather_data.head()
# Out:
#        STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1NYWC0003  WHITE PLAINS 3.1 NNW, NY US   41.0639   -73.7722       71.0
# 1  US1NYWC0003  WHITE PLAINS 3.1 NNW, NY US   41.0639   -73.7722       71.0
# 2  US1NYWC0003  WHITE PLAINS 3.1 NNW, NY US   41.0639   -73.7722       71.0
# 3  US1NYWC0003  WHITE PLAINS 3.1 NNW, NY US   41.0639   -73.7722       71.0
# 4  US1NYWC0003  WHITE PLAINS 3.1 NNW, NY US   41.0639   -73.7722       71.0
#
#          DATE  AWND  DAPR  DASF  MDPR  ...  WSF5  WT01  WT02  WT03  WT04  \
# 0  2017-01-03   NaN   4.0   NaN  0.08  ...   NaN   NaN   NaN   NaN   NaN
# 1  2017-01-04   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 2  2017-01-05   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3  2017-01-06   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4  2017-01-09   NaN   3.0   NaN  0.11  ...   NaN   NaN   NaN   NaN   NaN
#
#    WT05  WT06  WT08  WT09  WT11
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 36 columns]

# %%
#check distribution of precipitationa
weather_data.PRCP.sort_values(ascending=False).hist()
# Out:
# <AxesSubplot:>

# %%
weather_data[weather_data.DATE=='2017-01-01'].PRCP.mean()
# Out:
# 0.0016129032258064516

# %%
mylist=weather_data.columns.tolist()[6:]

# %%
weather_data_mean=weather_data.groupby('DATE').mean().reset_index()

# %%
weather_data_mean
# Out:
#             DATE   LATITUDE  LONGITUDE  ELEVATION    AWND  DAPR  DASF   MDPR  \
# 0     2017-01-01  40.739623 -73.659958  26.219355   8.188   NaN   NaN    NaN
# 1     2017-01-02  40.746496 -73.637707  26.245161   9.128   NaN   NaN    NaN
# 2     2017-01-03  40.742774 -73.633086  25.808333  12.304   4.0   NaN  0.240
# 3     2017-01-04  40.746452 -73.662010  26.008571  12.706   2.0   NaN  0.880
# 4     2017-01-05  40.750996 -73.642144  27.927273  12.256   NaN   NaN    NaN
# ...          ...        ...        ...        ...     ...   ...   ...    ...
# 1090  2019-12-27  40.774242 -73.709234  33.800000   6.486   NaN   NaN    NaN
# 1091  2019-12-28  40.766908 -73.698128  31.284615   7.026   NaN   NaN    NaN
# 1092  2019-12-29  40.775556 -73.712105  31.774074   6.038  11.0   NaN  0.020
# 1093  2019-12-30  40.772581 -73.695824  31.224138  15.882   NaN   NaN    NaN
# 1094  2019-12-31  40.772632 -73.693264  31.264516   8.278   3.5   NaN  0.945
#
#       MDSF    PGTM  ...   WSF5  WT01  WT02  WT03  WT04  WT05  WT06  WT08  \
# 0      NaN  1031.0  ...  25.82   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# 1      NaN  2097.5  ...  21.20   1.0   NaN   NaN   1.0   NaN   NaN   1.0
# 2      NaN  1237.0  ...  28.42   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3      NaN  1832.0  ...  38.54   1.0   NaN   NaN   NaN   NaN   NaN   1.0
# 4      NaN    23.0  ...  30.44   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...     ...  ...    ...   ...   ...   ...   ...   ...   ...   ...
# 1090   NaN  1148.0  ...  19.98   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1091   NaN   618.5  ...  19.44   1.0   NaN   NaN   NaN   NaN   NaN   1.0
# 1092   NaN  2335.0  ...  18.02   1.0   NaN   NaN   NaN   NaN   NaN   NaN
# 1093   NaN  1422.5  ...  40.32   1.0   NaN   NaN   NaN   NaN   NaN   1.0
# 1094   NaN  1029.5  ...  26.84   1.0   NaN   NaN   NaN   NaN   NaN   NaN
#
#       WT09  WT11
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ...    ...   ...
# 1090   NaN   NaN
# 1091   NaN   NaN
# 1092   NaN   NaN
# 1093   NaN   NaN
# 1094   NaN   NaN
#
# [1095 rows x 34 columns]

# %% [markdown]
# ## MTA data

# %%
mta_daily=pd.read_csv('mta_total_daily.csv', sep='\t', index_col=0)

# %%
mta_daily
# Out:
#           DATE  DAILY_ENTRIES    MONTH
# 0   2014-12-28      2814375.0  2014-12
# 1   2014-12-29      5103288.0  2014-12
# 2   2014-12-30      5296417.0  2014-12
# 3   2014-12-31      4796475.0  2014-12
# 4   2015-01-01      2731483.0  2015-01
# ..         ...            ...      ...
# 15  2022-01-10      1977437.0  2022-01
# 16  2022-01-11      1851748.0  2022-01
# 17  2022-01-12      2158086.0  2022-01
# 18  2022-01-13      2114752.0  2022-01
# 19  2022-01-14      2170819.0  2022-01
#
# [2570 rows x 3 columns]

# %% [markdown]
# ## Merging and plotting data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.merge(mta_daily, weather_data_mean, on='DATE', how='inner')

# %%
df
# Out:
#             DATE  DAILY_ENTRIES    MONTH   LATITUDE  LONGITUDE  ELEVATION  \
# 0     2017-01-01      2627365.0  2017-01  40.739623 -73.659958  26.219355
# 1     2017-01-02      2867392.0  2017-01  40.746496 -73.637707  26.245161
# 2     2017-01-03      5470453.0  2017-01  40.742774 -73.633086  25.808333
# 3     2017-01-04      5894501.0  2017-01  40.746452 -73.662010  26.008571
# 4     2017-01-05      5864375.0  2017-01  40.750996 -73.642144  27.927273
# ...          ...            ...      ...        ...        ...        ...
# 1089  2019-12-27      4533088.0  2019-12  40.774242 -73.709234  33.800000
# 1090  2019-12-28      3440375.0  2019-12  40.766908 -73.698128  31.284615
# 1091  2019-12-29      2721517.0  2019-12  40.775556 -73.712105  31.774074
# 1092  2019-12-30      4542705.0  2019-12  40.772581 -73.695824  31.224138
# 1093  2019-12-31      4338852.0  2019-12  40.772632 -73.693264  31.264516
#
#         AWND  DAPR  DASF   MDPR  ...   WSF5  WT01  WT02  WT03  WT04  WT05  \
# 0      8.188   NaN   NaN    NaN  ...  25.82   NaN   NaN   NaN   NaN   NaN
# 1      9.128   NaN   NaN    NaN  ...  21.20   1.0   NaN   NaN   1.0   NaN
# 2     12.304   4.0   NaN  0.240  ...  28.42   1.0   NaN   NaN   NaN   NaN
# 3     12.706   2.0   NaN  0.880  ...  38.54   1.0   NaN   NaN   NaN   NaN
# 4     12.256   NaN   NaN    NaN  ...  30.44   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...    ...  ...    ...   ...   ...   ...   ...   ...
# 1089   6.486   NaN   NaN    NaN  ...  19.98   1.0   NaN   NaN   NaN   NaN
# 1090   7.026   NaN   NaN    NaN  ...  19.44   1.0   NaN   NaN   NaN   NaN
# 1091   6.038  11.0   NaN  0.020  ...  18.02   1.0   NaN   NaN   NaN   NaN
# 1092  15.882   NaN   NaN    NaN  ...  40.32   1.0   NaN   NaN   NaN   NaN
# 1093   8.278   3.5   NaN  0.945  ...  26.84   1.0   NaN   NaN   NaN   NaN
#
#       WT06  WT08  WT09  WT11
# 0      NaN   1.0   NaN   NaN
# 1      NaN   1.0   NaN   NaN
# 2      NaN   NaN   NaN   NaN
# 3      NaN   1.0   NaN   NaN
# 4      NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...
# 1089   NaN   NaN   NaN   NaN
# 1090   NaN   1.0   NaN   NaN
# 1091   NaN   NaN   NaN   NaN
# 1092   NaN   1.0   NaN   NaN
# 1093   NaN   NaN   NaN   NaN
#
# [1094 rows x 36 columns]

# %%
#precipitation vs mta
ax = sns.regplot(x="PRCP", y="DAILY_ENTRIES", data=df)

# %%
df_zero=df.fillna(0)

# %%
#precipitation vs mta
#nan replaced with zeros
ax = sns.regplot(x="PRCP", y="DAILY_ENTRIES", data=df_zero)

# %%
#get list of independent variables
mylist=df_zero.columns.tolist()[6:]
len(mylist)
# Out:
# 30

# %%
fig, ax = plt.subplots(nrows=15,ncols=2,figsize=(10,100))

for i,var in enumerate(mylist[:15]):
    #state_cpm = state + "_" + "cpm"
    #state_spend = state + "_" + "spend"

    sns.regplot(data=df_zero, x=var, y="DAILY_ENTRIES",
                ax=ax[i,0]
               )
    
for i,var in enumerate(mylist[15:]):
    #state_cpm = state + "_" + "cpm"
    #state_spend = state + "_" + "spend"

    sns.regplot(data=df_zero, x=var, y="DAILY_ENTRIES",
                ax=ax[i,1]
               )

# %%
for i,b in enumerate(mylist[15:]):
    print (i, b)
# Out:
# 0 WDF2
# 1 WDF5
# 2 WESD
# 3 WESF
# 4 WSF2
# 5 WSF5
# 6 WT01
# 7 WT02
# 8 WT03
# 9 WT04
# 10 WT05
# 11 WT06
# 12 WT08
# 13 WT09
# 14 WT11

# %%
from matplotlib.ticker import FuncFormatter

# %%
#final plots
#https://learndataanalysis.org/source-code-format-axis-label-to-thousands-and-millions-suffix-matplotlib-tutorial/
#https://stackoverflow.com/questions/61330427/set-y-axis-in-millions
#Format Axis Label To Thousands and Millions Suffix
def millions_formatter(x, pos):
    return f'{x / 1000000}M'


fig, ax = plt.subplots(nrows=1,ncols=3,figsize=(15,5))

fig.suptitle('Weather vs MTA Ridership (2017-2019)')


sns.regplot(data=df_zero, x='PRCP', y="DAILY_ENTRIES",
            ax=ax[0]
            )
ax[0].set_xlabel( "Precipitation" , size = 12 )
ax[0].set_ylabel( "Daily MTA Entries" , size = 12 )
#ax[0].set_title( "Bill vs Tips" , size = 24 )


sns.regplot(data=df_zero, x='SNWD', y="DAILY_ENTRIES",
            ax=ax[1]
            )
ax[1].set_xlabel( "Snow Depth" , size = 12 )
ax[1].set_ylabel( "" , size = 12 )
#ax[1].set_title( "Bill vs Tips" , size = 24 )

sns.regplot(data=df_zero, x='TAVG', y="DAILY_ENTRIES",
            ax=ax[2]
            )  
ax[2].set_xlabel( "Average Temperature" , size = 12 )
ax[2].set_ylabel( "" , size = 12 )
#ax[2].set_title( "Bill vs Tips" , size = 24 )

ax[0].yaxis.set_major_formatter(FuncFormatter(millions_formatter))
ax[1].yaxis.set_major_formatter(FuncFormatter(millions_formatter))
ax[2].yaxis.set_major_formatter(FuncFormatter(millions_formatter))

sns.set(font_scale = 2)
fig.figure.savefig("Weather_MTA.png", dpi=1200)

# %%
#Plotting NYC covid overlayed with MTA data
#plt.figure( figsize = (10, 10))

#https://learndataanalysis.org/source-code-format-axis-label-to-thousands-and-millions-suffix-matplotlib-tutorial/
#https://stackoverflow.com/questions/61330427/set-y-axis-in-millions
#Format Axis Label To Thousands and Millions Suffix
def millions_formatter(x, pos):
    return f'{x / 1000000}M'


fig, ax = plt.subplots(figsize=(12,8))


xticks=total_monthly.MONTH[::5]
xlabels=total_monthly.MONTH[::5]

ax.set_facecolor('white')
sns.set_style("whitegrid")
sns.set_context("poster")
sns.despine()

ax=sns.lineplot(data=total_monthly,
                x = 'MONTH',
                y = 'MONTHLY_ENTRIES',
                label = 'MTA Monthly Entries',
                legend=False,
                color='darkturquoise'
               )

sns.lineplot(data=total_monthly,
             x = 'MONTH',
             y = 'rolling_monthly_entries',
             label = 'MTA Monthly Rolling',
             ax=ax,
             color="goldenrod",
             linestyle='--',
             legend=False
             )

ax2 = ax.twinx()
                
sns.lineplot(data=uberlyft_data,
             x = 'MONTH',
             y = 'Total Dispatched Trips',
             label = 'Uber/Lyft Monthly Trips',
             ax=ax2,
             #color="mediumorchid",
             hue="Base Name",
             palette={'LYFT':'magenta','UBER':'black'},
             legend=False
             )

#ax.yaxis.grid(False)
#ax2.yaxis.grid(False)
#ax.xaxis.grid(False)
#ax2.xaxis.grid(False)

#xticks=NYC_COVID_Data.date[::90] #only show tick for every 90 days
#xlabels=NYC_COVID_Data.abbrev_date[::90] #only show tick for every 90 days

#ax.set_xticklabels(labels=xlabels, rotation=30)

#plt.xlabel("aergaerg"
           #, fontsize = 20
          #)

#plt.ylabel("Daily Cases"
           #, fontsize = 20
          #)

ax.set_ylabel('Monthly MTA Entries', fontsize = 15)
ax2.set_ylabel('Monthly Uber/Lyft Entries', fontsize = 15)
ax.set_xlabel('Date', fontsize = 15)


#plt.tight_layout()
#plt.legend(fontsize = 20)

plt.title("2019-2022 NYC Ridershare MTA Data"
          #, fontsize = 30
         )

fig.legend(labels=["MTA",'MTA 6 Month Rolling',"Uber",'Lyft'],fontsize = 15)

ax2.set_ylim(0,80000000)


ax.xaxis.set_ticks(xticks)
ax.xaxis.set_ticklabels(xlabels, rotation=45, fontsize = 15)

ax.set_yticklabels(ax.get_yticks(), size = 13)
ax2.set_yticklabels(ax2.get_yticks(), size = 13)
#ax.set_xticklabels(ax2.get_xticklabels(), rotation=45)

ax.yaxis.set_major_formatter(FuncFormatter(millions_formatter))
ax2.yaxis.set_major_formatter(FuncFormatter(millions_formatter))

fig.tight_layout()
sns.set(font_scale = 1)

fig.figure.savefig("Uber_MTA.png", dpi=1200)
